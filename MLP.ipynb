# %%
import numpy as np;
import pandas as pd;

# %%
df = pd.read_csv("training data.csv")
df
# Out:
#         PM2.5    PM10     NO     NO2     NOx    NH3    CO    SO2      O3  \
# 0       71.36  115.75   1.75   20.65   12.40  12.19  0.10  10.76  109.26
# 1       81.40  124.50   1.44   20.50   12.08  10.72  0.12  15.24  127.09
# 2       78.32  129.06   1.26   26.00   14.85  10.28  0.14  26.96  117.44
# 3       88.76  135.32   6.60   30.85   21.77  12.91  0.11  33.59  111.81
# 4       64.18  104.09   2.56   28.07   17.01  11.42  0.09  19.00  138.18
# ...       ...     ...    ...     ...     ...    ...   ...    ...     ...
# 108030   8.65   16.46    NaN     NaN     NaN    NaN  0.69   4.36   30.59
# 108031  11.80   18.47    NaN     NaN     NaN    NaN  0.68   3.49   38.95
# 108032  18.60   32.26  13.65  200.87  214.20  11.40  0.78   5.12   38.17
# 108033  16.07   39.30   7.56   29.13   36.69  29.26  0.69   5.88   29.64
# 108034  10.50   36.50   7.78   22.50   30.25  27.23  0.58   2.80   13.10
#
#           AQI
# 0         NaN
# 1       184.0
# 2       197.0
# 3       198.0
# 4       188.0
# ...       ...
# 108030   50.0
# 108031   65.0
# 108032   63.0
# 108033   57.0
# 108034   59.0
#
# [108035 rows x 10 columns]

# %%
df.head()
# Out:
#    PM2.5    PM10    NO    NO2    NOx    NH3    CO    SO2      O3    AQI
# 0  71.36  115.75  1.75  20.65  12.40  12.19  0.10  10.76  109.26    NaN
# 1  81.40  124.50  1.44  20.50  12.08  10.72  0.12  15.24  127.09  184.0
# 2  78.32  129.06  1.26  26.00  14.85  10.28  0.14  26.96  117.44  197.0
# 3  88.76  135.32  6.60  30.85  21.77  12.91  0.11  33.59  111.81  198.0
# 4  64.18  104.09  2.56  28.07  17.01  11.42  0.09  19.00  138.18  188.0

# %%
df.drop(columns=['NOx'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108035 entries, 0 to 108034
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PM2.5   86410 non-null  float64
#  1   PM10    65329 non-null  float64
#  2   NO      90929 non-null  float64
#  3   NO2     91488 non-null  float64
#  4   NH3     59930 non-null  float64
#  5   CO      95037 non-null  float64
#  6   SO2     82831 non-null  float64
#  7   O3      82467 non-null  float64
#  8   AQI     87025 non-null  float64
# dtypes: float64(9)
# memory usage: 7.4 MB

# %%
import seaborn as sns

# %%
sns.displot(df['AQI'])

# %%
df.sample(10)
# Out:
#        PM2.5    PM10     NO    NO2    NH3    CO    SO2     O3    AQI
# 32976  84.59  121.50   2.40  27.64  26.87  0.30   9.86  67.12  243.0
# 84343  36.52   96.82   1.71  22.27  29.90  0.39   9.55  21.75  101.0
# 61500    NaN   95.84  15.48  48.54    NaN  1.26   6.39    NaN   99.0
# 99755  89.15     NaN  21.12  32.29    NaN  1.14   6.76  12.45  166.0
# 94307  11.28     NaN   3.44   7.73   2.24  0.72   7.02  94.77  122.0
# 4219   79.63     NaN   7.04  10.82    NaN  1.18  46.70  83.86  189.0
# 11741  45.43   82.45  25.36  45.28    NaN  0.52    NaN   8.46   85.0
# 1681   32.22   91.28   1.51  37.53  10.45  0.56  13.10  21.67   79.0
# 76242  37.66  104.22   2.25   8.13   4.03  0.37   4.37  54.93  104.0
# 51789    NaN     NaN    NaN    NaN    NaN   NaN    NaN    NaN    NaN

# %%
df.corr()['AQI']
# Out:
# PM2.5    0.814845
# PM10     0.885070
# NO       0.476714
# NO2      0.499207
# NH3      0.440643
# CO       0.448148
# SO2      0.393349
# O3       0.175122
# AQI      1.000000
# Name: AQI, dtype: float64

# %%
y=pd.DataFrame(df)

# %%
if y.isnull().values.any():
    df=y.dropna(inplace=True)
    
y
# Out:
#         PM2.5    PM10     NO     NO2    NH3    CO    SO2      O3    AQI
# 1       81.40  124.50   1.44   20.50  10.72  0.12  15.24  127.09  184.0
# 2       78.32  129.06   1.26   26.00  10.28  0.14  26.96  117.44  197.0
# 3       88.76  135.32   6.60   30.85  12.91  0.11  33.59  111.81  198.0
# 4       64.18  104.09   2.56   28.07  11.42  0.09  19.00  138.18  188.0
# 5       72.47  114.84   5.23   23.20  12.25  0.16  10.55  109.74  173.0
# ...       ...     ...    ...     ...    ...   ...    ...     ...    ...
# 108028  17.03   39.64   3.23   11.42  18.98  0.57  11.39   31.76   56.0
# 108029   9.79   19.87  23.51   16.50  25.09  0.66  10.34   30.19   50.0
# 108032  18.60   32.26  13.65  200.87  11.40  0.78   5.12   38.17   63.0
# 108033  16.07   39.30   7.56   29.13  29.26  0.69   5.88   29.64   57.0
# 108034  10.50   36.50   7.78   22.50  27.23  0.58   2.80   13.10   59.0
#
# [47386 rows x 9 columns]

# %%
y.sample(100)
# Out:
#         PM2.5    PM10     NO     NO2    NH3    CO    SO2     O3    AQI
# 69688   25.02   48.83   7.51   12.20   7.51  0.32   2.87  14.08   46.0
# 30595   31.15  125.10   6.83   19.51  39.59  0.68   9.89  17.97  107.0
# 10740   44.06   70.70   3.54  158.63  36.49  0.58   5.31  18.81  113.0
# 82826   49.29   87.36  10.41   18.10  29.03  0.67  12.87  60.11  140.0
# 43481  208.10  388.80  98.71   65.55  17.96  3.01  14.45  65.47  333.0
# ...       ...     ...    ...     ...    ...   ...    ...    ...    ...
# 91602   34.27   63.89   2.69   27.30   7.03  0.45   1.84  32.75   63.0
# 42942   25.77   40.78  13.59   38.21  31.13  0.85  15.49  79.06   87.0
# 15913   46.10  113.51   7.61   27.91   9.15  0.54  10.71  77.09  151.0
# 34671  162.26  253.46  19.52   51.15  36.10  2.09  13.10  45.02  316.0
# 86533   34.42   56.60  12.24   16.39   7.86  0.61   1.27  18.29   78.0
#
# [100 rows x 9 columns]

# %%
sns.heatmap(y.corr())
# Out:
# <Axes: >

# %%
sns.displot(np.log(y['AQI']))

# %%
X= y.drop(columns=['AQI'])
Y= np.log(y['AQI'])

# %%
X
# Out:
#         PM2.5    PM10     NO     NO2    NH3    CO    SO2      O3
# 1       81.40  124.50   1.44   20.50  10.72  0.12  15.24  127.09
# 2       78.32  129.06   1.26   26.00  10.28  0.14  26.96  117.44
# 3       88.76  135.32   6.60   30.85  12.91  0.11  33.59  111.81
# 4       64.18  104.09   2.56   28.07  11.42  0.09  19.00  138.18
# 5       72.47  114.84   5.23   23.20  12.25  0.16  10.55  109.74
# ...       ...     ...    ...     ...    ...   ...    ...     ...
# 108028  17.03   39.64   3.23   11.42  18.98  0.57  11.39   31.76
# 108029   9.79   19.87  23.51   16.50  25.09  0.66  10.34   30.19
# 108032  18.60   32.26  13.65  200.87  11.40  0.78   5.12   38.17
# 108033  16.07   39.30   7.56   29.13  29.26  0.69   5.88   29.64
# 108034  10.50   36.50   7.78   22.50  27.23  0.58   2.80   13.10
#
# [47386 rows x 8 columns]

# %%
Y
# Out:
# 1         5.214936
# 2         5.283204
# 3         5.288267
# 4         5.236442
# 5         5.153292
#             ...
# 108028    4.025352
# 108029    3.912023
# 108032    4.143135
# 108033    4.043051
# 108034    4.077537
# Name: AQI, Length: 47386, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=.4,random_state=2)

# %%
X_train
# Out:
#          PM2.5    PM10     NO    NO2     NH3    CO    SO2     O3
# 94107    12.66   27.06   8.29   6.37   23.54  0.45   7.57  67.29
# 34718   421.14  580.23  49.04  76.69  103.25  2.29  22.62  32.76
# 33067    74.40  227.80   2.01  29.83   30.27  0.32  34.05  90.40
# 79046    49.08   71.10  53.40   6.95   11.32  0.00   3.56   5.68
# 27815    83.12  148.56  56.95  50.70   34.12  1.16  13.75  14.14
# ...        ...     ...    ...    ...     ...   ...    ...    ...
# 104987  129.65  198.86  76.93  42.58   40.32  1.55  10.46  34.98
# 70481    24.32   49.88   1.13   6.30    2.55  0.82   0.96  33.61
# 15245    21.35   55.78   3.77  28.57   80.67  0.69  18.49  11.77
# 79103    32.01   57.41  10.85   7.65   11.00  0.59   7.43   5.76
# 48075    50.92   67.84   9.41  16.42   32.32  1.03   5.53  32.54
#
# [28431 rows x 8 columns]

# %% [markdown]
# # MODEL (testing and training)

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.pipeline import Pipeline 
from sklearn.compose import ColumnTransformer 
from sklearn.preprocessing import OneHotEncoder

from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False,drop='first'),[])
], remainder='passthrough')

step2 = LinearRegression()
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 Score', r2_score(Y_test,y_pred))
print('MAE', mean_absolute_error(Y_test,y_pred))
# Out:
# R2 Score 0.7631498303585489
# MAE 0.2497087670537936

# %%
np.exp(0.2497087670537936)
# Out:
# 1.2836515206307035

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False,drop='first'),[])
], remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 Score', r2_score(Y_test,y_pred))
print('MAE', mean_absolute_error(Y_test,y_pred))
# Out:
# R2 Score 0.7631494322845027
# MAE 0.24970877855129403

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False,drop='first'),[])
], remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 Score', r2_score(Y_test,y_pred))
print('MAE', mean_absolute_error(Y_test,y_pred))
# Out:
# R2 Score 0.7631235712410026
# MAE 0.24970847727000764

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False,drop='first'),[])
], remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=7)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 Score', r2_score(Y_test,y_pred))
print('MAE', mean_absolute_error(Y_test,y_pred))
# Out:
# R2 Score 0.9300175653888131
# MAE 0.1300595664117278

# %% [markdown]
# step1 = ColumnTransformer(transformers=[
#     ('col_tnf', OneHotEncoder(sparse=False,drop='first'),[])
# ], remainder='passthrough')
#
# step2 = KNeighborsRegressor(n_neighbors=3)
#
# pipe = Pipeline([
#     ('step1',step1),
#     ('step2',step2)
# ])
#
# pipe.fit(X_train,Y_train)
#
# y_pred = pipe.predict(X_test)
#
# print('R2 Score', r2_score(Y_test,y_pred))
# print('MAE', mean_absolute_error(Y_test,y_pred))

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False,drop='first'),[])
], remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=11)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 Score', r2_score(Y_test,y_pred))
print('MAE', mean_absolute_error(Y_test,y_pred))
# Out:
# R2 Score 0.9278249060864442
# MAE 0.1299450964732414

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False,drop='first'),[])
], remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=.4)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 Score', r2_score(Y_test,y_pred))
print('MAE', mean_absolute_error(Y_test,y_pred))

# %% [markdown]
# # Random Forest Tree

# %% [raw]
# #

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False,drop='first'),[])
], remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,random_state=3,max_samples=0.5, max_features=0.75,max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 Score', r2_score(Y_test,y_pred))
print('MAE', mean_absolute_error(Y_test,y_pred))
# Out:
# R2 Score 0.9439431264351192
# MAE 0.11617012232759084

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False,drop='first'),[])
], remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=.5,bootstrap=True, max_features=0.75,max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 Score', r2_score(Y_test,y_pred))
print('MAE', mean_absolute_error(Y_test,y_pred))
# Out:
# R2 Score 0.9423670761854123
# MAE 0.11893509523530468

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False,drop='first'),[])
], remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 Score', r2_score(Y_test,y_pred))
print('MAE', mean_absolute_error(Y_test,y_pred))
# Out:
# R2 Score 0.8886660096957771
# MAE 0.1760064472430602

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False,drop='first'),[])
], remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,Y_train)

y_pred = pipe.predict(X_test)

print('R2 Score', r2_score(Y_test,y_pred))
print('MAE', mean_absolute_error(Y_test,y_pred))
# Out:
# R2 Score 0.9413529065606288
# MAE 0.12029205372219642

# %% [markdown]
# # Exporting the Data

# %%
import pickle
pickle.dump(y,open('y.pkl', 'wb'))
pickle.dump(pipe,open('pipe.pkl', 'wb'))

# %%
y
# Out:
#         PM2.5    PM10     NO     NO2    NH3    CO    SO2      O3    AQI
# 1       81.40  124.50   1.44   20.50  10.72  0.12  15.24  127.09  184.0
# 2       78.32  129.06   1.26   26.00  10.28  0.14  26.96  117.44  197.0
# 3       88.76  135.32   6.60   30.85  12.91  0.11  33.59  111.81  198.0
# 4       64.18  104.09   2.56   28.07  11.42  0.09  19.00  138.18  188.0
# 5       72.47  114.84   5.23   23.20  12.25  0.16  10.55  109.74  173.0
# ...       ...     ...    ...     ...    ...   ...    ...     ...    ...
# 108028  17.03   39.64   3.23   11.42  18.98  0.57  11.39   31.76   56.0
# 108029   9.79   19.87  23.51   16.50  25.09  0.66  10.34   30.19   50.0
# 108032  18.60   32.26  13.65  200.87  11.40  0.78   5.12   38.17   63.0
# 108033  16.07   39.30   7.56   29.13  29.26  0.69   5.88   29.64   57.0
# 108034  10.50   36.50   7.78   22.50  27.23  0.58   2.80   13.10   59.0
#
# [47386 rows x 9 columns]
